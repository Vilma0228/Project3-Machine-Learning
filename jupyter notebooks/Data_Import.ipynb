# %%
#Import Dependencies
import pandas as pd 
import os

# %%
#Read in the beds files
csv_file_1 = os.path.join("RDC_Inventory_current_county_bdrs_1.csv")
bed_1 = pd.read_csv(csv_file_1)
csv_file_2 = os.path.join("RDC_Inventory_current_county_bdrs_2.csv")
bed_2 = pd.read_csv(csv_file_2)
csv_file_3 = os.path.join("RDC_Inventory_current_county_bdrs_3.csv")
bed_3 = pd.read_csv(csv_file_3)
csv_file_4 = os.path.join("RDC_Inventory_current_county_bdrs_4.csv")
bed_4 = pd.read_csv(csv_file_4)
csv_file_5 = os.path.join("RDC_Inventory_current_county_bdrs_5%2B.csv")
bed_5 = pd.read_csv(csv_file_5)

# %%
bed_2
# Out:
#                                                   Month  Countyfips  \
# 0                                                201808     22017.0
# 1                                                201808     39159.0
# 2                                                201808     23003.0
# 3                                                201808     17195.0
# 4                                                201808     48171.0
# 5                                                201808      1031.0
# 6                                                201808     42111.0
# 7                                                201808     19063.0
# 8                                                201808     51520.0
# 9                                                201808     53035.0
# 10                                               201808      5125.0
# 11                                               201808     36007.0
# 12                                               201808     12063.0
# ...

# %%
bed_data = pd.concat([bed_1, bed_2, bed_3, bed_4, bed_5])
bed_data
# Out:
#                                                   Month  Countyfips  \
# 0                                                201808     19063.0
# 1                                                201808     37067.0
# 2                                                201808     34011.0
# 3                                                201808      6077.0
# 4                                                201808      9007.0
# 5                                                201808     36033.0
# 6                                                201808     17163.0
# 7                                                201808     16085.0
# 8                                                201808     34023.0
# 9                                                201808     37031.0
# 10                                               201808     26071.0
# 11                                               201808     47065.0
# 12                                               201808     49033.0
# ...

# %%
bed_data.Month.unique()
# Out:
# array(['201808',
#        'QualityFlagPending = 1: Year-over-year figures are impacted in this area by MLS changes to the pending status definition. please contact economics@realtor.com for more details.',
#        'QualityFlagSqft = 1: Square foot data in this area is inconsistent or unavailable. Usage of square foot metrics for this area should be avoided. Please contact economics@realtor.com for more details.'],
#       dtype=object)

# %%
bed_data = bed_data[bed_data.Month != "QualityFlagPending = 1: Year-over-year figures are impacted in this area by MLS changes to the pending status definition. please contact economics@realtor.com for more details."]
bed_data
# Out:
#                                                   Month  Countyfips  \
# 0                                                201808     19063.0
# 1                                                201808     37067.0
# 2                                                201808     34011.0
# 3                                                201808      6077.0
# 4                                                201808      9007.0
# 5                                                201808     36033.0
# 6                                                201808     17163.0
# 7                                                201808     16085.0
# 8                                                201808     34023.0
# 9                                                201808     37031.0
# 10                                               201808     26071.0
# 11                                               201808     47065.0
# 12                                               201808     49033.0
# ...

# %%
bed_data = bed_data[bed_data.Month != 'QualityFlagSqft = 1: Square foot data in this area is inconsistent or unavailable. Usage of square foot metrics for this area should be avoided. Please contact economics@realtor.com for more details.']

# %%
bed_data
# Out:
#        Month  Countyfips             CountyName Country  \
# 0     201808     19063.0              Emmet, IA     USA
# 1     201808     37067.0            Forsyth, NC     USA
# 2     201808     34011.0         Cumberland, NJ     USA
# 3     201808      6077.0        San Joaquin, CA     USA
# 4     201808      9007.0          Middlesex, CT     USA
# 5     201808     36033.0           Franklin, NY     USA
# 6     201808     17163.0          St. Clair, IL     USA
# 7     201808     16085.0             Valley, ID     USA
# 8     201808     34023.0          Middlesex, NJ     USA
# 9     201808     37031.0           Carteret, NC     USA
# 10    201808     26071.0               Iron, MI     USA
# 11    201808     47065.0           Hamilton, TN     USA
# 12    201808     49033.0               Rich, UT     USA
# 13    201808     13121.0             Fulton, GA     USA
# 14    201808     45083.0        Spartanburg, SC     USA
# 15    201808     34031.0            Passaic, NJ     USA
# ...

# %%
list(bed_data)
# Out:
# ['Month',
#  'Countyfips',
#  'CountyName',
#  'Country',
#  'PropertyType',
#  'NoOfBdrs',
#  'MedianListingPrice ',
#  'MedianListingPrice M/M',
#  'MedianListingPrice Y/Y',
#  'MedianListingSqft ',
#  'MedianListingSqft M/M',
#  'MedianListingSqft Y/Y',
#  'MedianListingPricePerSqft',
#  'MedianListingPricePerSqft M/M',
#  'MedianListingPricePerSqft Y/Y',
#  'ActiveListingCount',
#  'ActiveListingCount M/M',
#  'ActiveListingCount Y/Y',
#  'DOMUnder30',
#  'DOMUnder30 M/M',
#  'DOMUnder30 Y/Y',
#  'Median DOM',
#  'Median DOM M/M',
#  'Median DOM M/M Perc',
#  'Median DOM Y/Y',
#  'Median DOM Y/Y Perc',
#  'NewListingCount',
#  'NewListingCount M/M',
#  'NewListingCount Y/Y',
#  'PriceIncreasedCount',
#  'PriceIncreasedCount M/M',
#  'PriceIncreasedCount Y/Y',
#  'PriceReducedCount',
#  'PriceReducedCount M/M',
#  'PriceReducedCount Y/Y',
#  'PendingListingCount',
#  'PendingListingCount M/M',
#  'PendingListingCount Y/Y',
#  'TotalListingCount',
#  'TotalListingCount M/M',
# ...

# %%
beds_df = bed_data.drop(columns=['ActiveListingCount', 'ActiveListingCount M/M', 'ActiveListingCount Y/Y', 'DOMUnder30', 'DOMUnder30 M/M', 'DOMUnder30 Y/Y', 'Median DOM', 'Median DOM M/M', 'Median DOM M/M Perc', 'Median DOM Y/Y', 'Median DOM Y/Y Perc', 'NewListingCount', 'NewListingCount M/M', 'NewListingCount Y/Y', 'PriceIncreasedCount', 'PriceIncreasedCount M/M', 'PriceIncreasedCount Y/Y', 'PriceReducedCount', 'PriceReducedCount M/M', 'PriceReducedCount Y/Y', 'PendingListingCount', 'PendingListingCount M/M', 'PendingListingCount Y/Y', 'TotalListingCount', 'TotalListingCount M/M', 'TotalListingCount Y/Y', 'PendingRatio', 'PendingRatio M/M', 'PendingRatio Y/Y', 'Views M/M', 'Views Y/Y', 'ViewsPerProperty M/M', 'ViewsPerProperty Y/Y', 'QualityFlagPending', 'QualityFlagSqft'
])

# %%
beds_df
# Out:
#        Month  Countyfips             CountyName Country  \
# 0     201808     19063.0              Emmet, IA     USA
# 1     201808     37067.0            Forsyth, NC     USA
# 2     201808     34011.0         Cumberland, NJ     USA
# 3     201808      6077.0        San Joaquin, CA     USA
# 4     201808      9007.0          Middlesex, CT     USA
# 5     201808     36033.0           Franklin, NY     USA
# 6     201808     17163.0          St. Clair, IL     USA
# 7     201808     16085.0             Valley, ID     USA
# 8     201808     34023.0          Middlesex, NJ     USA
# 9     201808     37031.0           Carteret, NC     USA
# 10    201808     26071.0               Iron, MI     USA
# 11    201808     47065.0           Hamilton, TN     USA
# 12    201808     49033.0               Rich, UT     USA
# 13    201808     13121.0             Fulton, GA     USA
# 14    201808     45083.0        Spartanburg, SC     USA
# 15    201808     34031.0            Passaic, NJ     USA
# ...

# %%
# read in price files
price_1 = os.path.join("RDC_Inventory_current_county_price_0_100k.csv")
price_100 = pd.read_csv(price_1)
price_2 = os.path.join("RDC_Inventory_current_county_price_100_200k.csv")
price_200 = pd.read_csv(price_2)
price_3 = os.path.join("RDC_Inventory_current_county_price_200_350k.csv")
price_350 = pd.read_csv(price_3)
price_4 = os.path.join("RDC_Inventory_current_county_price_350_500k.csv")
price_500 = pd.read_csv(price_4)
price_5 = os.path.join("RDC_Inventory_current_county_price_500_750k.csv")
price_750 = pd.read_csv(price_5)
price_6 = os.path.join("RDC_Inventory_current_county_price_750_1M.csv")
price_1m = pd.read_csv(price_6)
price_7 = os.path.join("RDC_Inventory_current_county_price_1Mplus.csv")
price_1mP = pd.read_csv(price_7)

# %%
price_data = pd.concat([price_100, price_200, price_350, price_500, price_750, price_1m, price_1mP])
price_data
# Out:
#                                                   Month  Countyfips  \
# 0                                                201808      1083.0
# 1                                                201808     16053.0
# 2                                                201808      4009.0
# 3                                                201808     36055.0
# 4                                                201808      8077.0
# 5                                                201808      6077.0
# 6                                                201808     35045.0
# 7                                                201808     37105.0
# 8                                                201808     36005.0
# 9                                                201808     40031.0
# 10                                               201808      6037.0
# 11                                               201808     17081.0
# 12                                               201808     27015.0
# ...

# %%
price_data = price_data[price_data.Month != "QualityFlagPending = 1: Year-over-year figures are impacted in this area by MLS changes to the pending status definition. please contact economics@realtor.com for more details."]
price_data
# Out:
#                                                   Month  Countyfips  \
# 0                                                201808      1083.0
# 1                                                201808     16053.0
# 2                                                201808      4009.0
# 3                                                201808     36055.0
# 4                                                201808      8077.0
# 5                                                201808      6077.0
# 6                                                201808     35045.0
# 7                                                201808     37105.0
# 8                                                201808     36005.0
# 9                                                201808     40031.0
# 10                                               201808      6037.0
# 11                                               201808     17081.0
# 12                                               201808     27015.0
# ...

# %%
price_data = price_data[price_data.Month != 'QualityFlagSqft = 1: Square foot data in this area is inconsistent or unavailable. Usage of square foot metrics for this area should be avoided. Please contact economics@realtor.com for more details.']

# %%
price_data = price_data.drop(columns=['ActiveListingCount', 'ActiveListingCount M/M', 'ActiveListingCount Y/Y', 'DOMUnder30', 'DOMUnder30 M/M', 'DOMUnder30 Y/Y', 'Median DOM', 'Median DOM M/M', 'Median DOM M/M Perc', 'Median DOM Y/Y', 'Median DOM Y/Y Perc', 'NewListingCount', 'NewListingCount M/M', 'NewListingCount Y/Y', 'PriceIncreasedCount', 'PriceIncreasedCount M/M', 'PriceIncreasedCount Y/Y', 'PriceReducedCount', 'PriceReducedCount M/M', 'PriceReducedCount Y/Y', 'PendingListingCount', 'PendingListingCount M/M', 'PendingListingCount Y/Y', 'TotalListingCount', 'TotalListingCount M/M', 'TotalListingCount Y/Y', 'PendingRatio', 'PendingRatio M/M', 'PendingRatio Y/Y', 'Views M/M', 'Views Y/Y', 'ViewsPerProperty M/M', 'ViewsPerProperty Y/Y', 'QualityFlagPending', 'QualityFlagSqft'
])

# %%
#Read in the beds files
sq1 = os.path.join("RDC_Inventory_current_county_sqft_0_750.csv")
sq750 = pd.read_csv(sq1)
sq2 = os.path.join("RDC_Inventory_current_county_sqft_750_1750.csv")
sq1750 = pd.read_csv(sq2)
sq3 = os.path.join("RDC_Inventory_current_county_sqft_1750_3000.csv")
sq3000 = pd.read_csv(sq3)
sq4 = os.path.join("RDC_Inventory_current_county_sqft_3000_6000.csv")
sq6000 = pd.read_csv(sq4)
sq5 = os.path.join("RDC_Inventory_current_county_sqft_6000plus.csv")
sq6p = pd.read_csv(sq5)

# %%
sq_data = pd.concat([sq750, sq1750, sq3000, sq6000, sq6p])
sq_data
# Out:
#                                                   Month  Countyfips  \
# 0                                                201808      8001.0
# 1                                                201808     36067.0
# 2                                                201808     37133.0
# 3                                                201808     24041.0
# 4                                                201808     25027.0
# 5                                                201808     47149.0
# 6                                                201808     13089.0
# 7                                                201808     48271.0
# 8                                                201808     39099.0
# 9                                                201808     12035.0
# 10                                               201808     18097.0
# 11                                               201808      6051.0
# 12                                               201808     12113.0
# ...

# %%
sq_data = sq_data[sq_data.Month != "QualityFlagPending = 1: Year-over-year figures are impacted in this area by MLS changes to the pending status definition. please contact economics@realtor.com for more details."]
sq_data
# Out:
#                                                   Month  Countyfips  \
# 0                                                201808      8001.0
# 1                                                201808     36067.0
# 2                                                201808     37133.0
# 3                                                201808     24041.0
# 4                                                201808     25027.0
# 5                                                201808     47149.0
# 6                                                201808     13089.0
# 7                                                201808     48271.0
# 8                                                201808     39099.0
# 9                                                201808     12035.0
# 10                                               201808     18097.0
# 11                                               201808      6051.0
# 12                                               201808     12113.0
# ...

# %%
sq_data = sq_data[sq_data.Month != 'QualityFlagSqft = 1: Square foot data in this area is inconsistent or unavailable. Usage of square foot metrics for this area should be avoided. Please contact economics@realtor.com for more details.']
sq_data
# Out:
#        Month  Countyfips           CountyName Country  \
# 0     201808      8001.0            Adams, CO     USA
# 1     201808     36067.0         Onondaga, NY     USA
# 2     201808     37133.0           Onslow, NC     USA
# 3     201808     24041.0           Talbot, MD     USA
# 4     201808     25027.0        Worcester, MA     USA
# 5     201808     47149.0       Rutherford, TN     USA
# 6     201808     13089.0           DeKalb, GA     USA
# 7     201808     48271.0           Kinney, TX     USA
# 8     201808     39099.0         Mahoning, OH     USA
# 9     201808     12035.0          Flagler, FL     USA
# 10    201808     18097.0           Marion, IN     USA
# 11    201808      6051.0             Mono, CA     USA
# 12    201808     12113.0       Santa Rosa, FL     USA
# 13    201808     19015.0            Boone, IA     USA
# 14    201808      6071.0   San Bernardino, CA     USA
# 15    201808      9001.0        Fairfield, CT     USA
# ...

# %%
sq_data.Month.unique()
# Out:
# array(['201808'], dtype=object)

# %%
sq_data = sq_data.drop(columns=['ActiveListingCount', 'ActiveListingCount M/M', 'ActiveListingCount Y/Y', 'DOMUnder30', 'DOMUnder30 M/M', 'DOMUnder30 Y/Y', 'Median DOM', 'Median DOM M/M', 'Median DOM M/M Perc', 'Median DOM Y/Y', 'Median DOM Y/Y Perc', 'NewListingCount', 'NewListingCount M/M', 'NewListingCount Y/Y', 'PriceIncreasedCount', 'PriceIncreasedCount M/M', 'PriceIncreasedCount Y/Y', 'PriceReducedCount', 'PriceReducedCount M/M', 'PriceReducedCount Y/Y', 'PendingListingCount', 'PendingListingCount M/M', 'PendingListingCount Y/Y', 'TotalListingCount', 'TotalListingCount M/M', 'TotalListingCount Y/Y', 'PendingRatio', 'PendingRatio M/M', 'PendingRatio Y/Y', 'Views M/M', 'Views Y/Y', 'ViewsPerProperty M/M', 'ViewsPerProperty Y/Y', 'QualityFlagPending', 'QualityFlagSqft'
])

# %%
sq_data
# Out:
#        Month  Countyfips           CountyName Country  \
# 0     201808      8001.0            Adams, CO     USA
# 1     201808     36067.0         Onondaga, NY     USA
# 2     201808     37133.0           Onslow, NC     USA
# 3     201808     24041.0           Talbot, MD     USA
# 4     201808     25027.0        Worcester, MA     USA
# 5     201808     47149.0       Rutherford, TN     USA
# 6     201808     13089.0           DeKalb, GA     USA
# 7     201808     48271.0           Kinney, TX     USA
# 8     201808     39099.0         Mahoning, OH     USA
# 9     201808     12035.0          Flagler, FL     USA
# 10    201808     18097.0           Marion, IN     USA
# 11    201808      6051.0             Mono, CA     USA
# 12    201808     12113.0       Santa Rosa, FL     USA
# 13    201808     19015.0            Boone, IA     USA
# 14    201808      6071.0   San Bernardino, CA     USA
# 15    201808      9001.0        Fairfield, CT     USA
# ...

# %%
bed_data.dtypes
# Out:
# Month                             object
# Countyfips                       float64
# CountyName                        object
# Country                           object
# PropertyType                      object
# NoOfBdrs                          object
# MedianListingPrice               float64
# MedianListingPrice M/M           float64
# MedianListingPrice Y/Y           float64
# MedianListingSqft                float64
# MedianListingSqft M/M            float64
# MedianListingSqft Y/Y            float64
# MedianListingPricePerSqft        float64
# MedianListingPricePerSqft M/M    float64
# MedianListingPricePerSqft Y/Y    float64
# ActiveListingCount               float64
# ActiveListingCount M/M           float64
# ActiveListingCount Y/Y           float64
# DOMUnder30                       float64
# DOMUnder30 M/M                   float64
# DOMUnder30 Y/Y                   float64
# Median DOM                       float64
# Median DOM M/M                   float64
# ...

# %%
beds_df['bed_id'] = beds_df['Countyfips'] + beds_df['MedianListingPricePerSqft']

# %%
beds_df
# Out:
#        Month  Countyfips             CountyName Country  \
# 0     201808     19063.0              Emmet, IA     USA
# 1     201808     37067.0            Forsyth, NC     USA
# 2     201808     34011.0         Cumberland, NJ     USA
# 3     201808      6077.0        San Joaquin, CA     USA
# 4     201808      9007.0          Middlesex, CT     USA
# 5     201808     36033.0           Franklin, NY     USA
# 6     201808     17163.0          St. Clair, IL     USA
# 7     201808     16085.0             Valley, ID     USA
# 8     201808     34023.0          Middlesex, NJ     USA
# 9     201808     37031.0           Carteret, NC     USA
# 10    201808     26071.0               Iron, MI     USA
# 11    201808     47065.0           Hamilton, TN     USA
# 12    201808     49033.0               Rich, UT     USA
# 13    201808     13121.0             Fulton, GA     USA
# 14    201808     45083.0        Spartanburg, SC     USA
# 15    201808     34031.0            Passaic, NJ     USA
# ...

# %%
sq_data['bed_id'] = sq_data['Countyfips'] + sq_data['MedianListingPricePerSqft']
sq_data
# Out:
#        Month  Countyfips           CountyName Country  \
# 0     201808      8001.0            Adams, CO     USA
# 1     201808     36067.0         Onondaga, NY     USA
# 2     201808     37133.0           Onslow, NC     USA
# 3     201808     24041.0           Talbot, MD     USA
# 4     201808     25027.0        Worcester, MA     USA
# 5     201808     47149.0       Rutherford, TN     USA
# 6     201808     13089.0           DeKalb, GA     USA
# 7     201808     48271.0           Kinney, TX     USA
# 8     201808     39099.0         Mahoning, OH     USA
# 9     201808     12035.0          Flagler, FL     USA
# 10    201808     18097.0           Marion, IN     USA
# 11    201808      6051.0             Mono, CA     USA
# 12    201808     12113.0       Santa Rosa, FL     USA
# 13    201808     19015.0            Boone, IA     USA
# 14    201808      6071.0   San Bernardino, CA     USA
# 15    201808      9001.0        Fairfield, CT     USA
# ...

# %%
price_data['bed_id'] = price_data['Countyfips'] + price_data['MedianListingPricePerSqft']
price_data
# Out:
#        Month  Countyfips           CountyName Country  \
# 0     201808      1083.0        Limestone, AL     USA
# 1     201808     16053.0           Jerome, ID     USA
# 2     201808      4009.0           Graham, AZ     USA
# 3     201808     36055.0           Monroe, NY     USA
# 4     201808      8077.0             Mesa, CO     USA
# 5     201808      6077.0      San Joaquin, CA     USA
# 6     201808     35045.0         San Juan, NM     USA
# 7     201808     37105.0              Lee, NC     USA
# 8     201808     36005.0            Bronx, NY     USA
# 9     201808     40031.0         Comanche, OK     USA
# 10    201808      6037.0      Los Angeles, CA     USA
# 11    201808     17081.0        Jefferson, IL     USA
# 12    201808     27015.0            Brown, MN     USA
# 13    201808     19041.0             Clay, IA     USA
# 14    201808     45015.0         Berkeley, SC     USA
# 15    201808     37071.0           Gaston, NC     USA
# ...

# %%
blanks = sum(pd.isnull(price_data['MedianListingPricePerSqft']))
blanks
# Out:
# 676

# %%
result1= pd.merge(sq_data, beds_df, on='bed_id', how='left')

# %%
home_df= pd.merge(result1, price_data, on='bed_id', how='left')
home_df
# Out:
#         Month_x  Countyfips_x         CountyName_x Country_x  \
# 0        201808        8001.0            Adams, CO       USA
# 1        201808       36067.0         Onondaga, NY       USA
# 2        201808       37133.0           Onslow, NC       USA
# 3        201808       24041.0           Talbot, MD       USA
# 4        201808       25027.0        Worcester, MA       USA
# 5        201808       47149.0       Rutherford, TN       USA
# 6        201808       13089.0           DeKalb, GA       USA
# 7        201808       48271.0           Kinney, TX       USA
# 8        201808       39099.0         Mahoning, OH       USA
# 9        201808       12035.0          Flagler, FL       USA
# 10       201808       18097.0           Marion, IN       USA
# 11       201808        6051.0             Mono, CA       USA
# 12       201808       12113.0       Santa Rosa, FL       USA
# 13       201808       12113.0       Santa Rosa, FL       USA
# ...

# %%
# home_df = home_df.rename(columns={'Size Tier': 'SizeTier', 'Property Type': 'Type'})

# %%
home_df
# Out:
#         Month_x  Countyfips_x         CountyName_x Country_x  \
# 0        201808        8001.0            Adams, CO       USA
# 1        201808       36067.0         Onondaga, NY       USA
# 2        201808       37133.0           Onslow, NC       USA
# 3        201808       24041.0           Talbot, MD       USA
# 4        201808       25027.0        Worcester, MA       USA
# 5        201808       47149.0       Rutherford, TN       USA
# 6        201808       13089.0           DeKalb, GA       USA
# 7        201808       48271.0           Kinney, TX       USA
# 8        201808       39099.0         Mahoning, OH       USA
# 9        201808       12035.0          Flagler, FL       USA
# 10       201808       18097.0           Marion, IN       USA
# 11       201808        6051.0             Mono, CA       USA
# 12       201808       12113.0       Santa Rosa, FL       USA
# 13       201808       12113.0       Santa Rosa, FL       USA
# ...

# %%
home_df = home_df.dropna(subset=["Size Tier"])
home_df
# Out:
#         Month_x  Countyfips_x         CountyName_x Country_x  \
# 0        201808        8001.0            Adams, CO       USA
# 1        201808       36067.0         Onondaga, NY       USA
# 2        201808       37133.0           Onslow, NC       USA
# 3        201808       24041.0           Talbot, MD       USA
# 4        201808       25027.0        Worcester, MA       USA
# 5        201808       47149.0       Rutherford, TN       USA
# 6        201808       13089.0           DeKalb, GA       USA
# 7        201808       48271.0           Kinney, TX       USA
# 8        201808       39099.0         Mahoning, OH       USA
# 9        201808       12035.0          Flagler, FL       USA
# 10       201808       18097.0           Marion, IN       USA
# 11       201808        6051.0             Mono, CA       USA
# 12       201808       12113.0       Santa Rosa, FL       USA
# 13       201808       12113.0       Santa Rosa, FL       USA
# ...

# %%
home_df = home_df.dropna(subset=["Price Tier"])
home_df
# Out:
#         Month_x  Countyfips_x      CountyName_x Country_x  \
# 5        201808       47149.0    Rutherford, TN       USA
# 14       201808       19015.0         Boone, IA       USA
# 21       201808       28105.0     Oktibbeha, MS       USA
# 28       201808        8093.0          Park, CO       USA
# 61       201808       26001.0        Alcona, MI       USA
# 69       201808       55099.0         Price, WI       USA
# 84       201808        8029.0         Delta, CO       USA
# 86       201808       46103.0    Pennington, SD       USA
# 87       201808       48121.0        Denton, TX       USA
# 89       201808       38063.0        Nelson, ND       USA
# 90       201808       38063.0        Nelson, ND       USA
# 128      201808       55137.0      Waushara, WI       USA
# 129      201808       48381.0       Randall, TX       USA
# 130      201808       48381.0       Randall, TX       USA
# 159      201808       29219.0        Warren, MO       USA
# ...

# %%
home_df = home_df.dropna(subset=["NoOfBdrs"])
home_df
# Out:
#         Month_x  Countyfips_x      CountyName_x Country_x  \
# 5        201808       47149.0    Rutherford, TN       USA
# 14       201808       19015.0         Boone, IA       USA
# 28       201808        8093.0          Park, CO       USA
# 61       201808       26001.0        Alcona, MI       USA
# 69       201808       55099.0         Price, WI       USA
# 84       201808        8029.0         Delta, CO       USA
# 87       201808       48121.0        Denton, TX       USA
# 89       201808       38063.0        Nelson, ND       USA
# 90       201808       38063.0        Nelson, ND       USA
# 128      201808       55137.0      Waushara, WI       USA
# 129      201808       48381.0       Randall, TX       USA
# 130      201808       48381.0       Randall, TX       USA
# 175      201808       56021.0       Laramie, WY       USA
# 183      201808       48209.0          Hays, TX       USA
# 199      201808       42009.0       Bedford, PA       USA
# ...

# %%
beds_df["MedianListingPricePerSqft"].value_counts()
# Out:
# 125.000000    16
# 100.000000    15
# 83.333333     13
# 50.000000     13
# 200.000000    12
# 75.000000     11
# 93.750000     11
# 62.500000     10
# 65.789474     10
# 78.125000     10
# 120.000000    10
# 86.805556      9
# 155.000000     9
# 171.875000     8
# 70.000000      8
# 66.666667      8
# 87.500000      8
# 96.153846      8
# 250.000000     8
# 55.000000      8
# 104.166667     8
# 54.166667      7
# 58.333333      7
# 69.444444      7
# 52.631579      6
# 109.375000     6
# 82.417582      6
# 85.937500      6
# 143.229167     6
# 138.461538     6
#               ..
# 259.660658     1
# 169.058175     1
# 1.063054       1
# 61.543367      1
# 95.873321      1
# 77.508500      1
# 73.457103      1
# 144.243590     1
# 121.792069     1
# 168.843682     1
# 388.994002     1
# 77.869135      1
# 73.943662      1
# 123.059782     1
# 594.116724     1
# 81.189084      1
# 116.051475     1
# 215.038445     1
# 132.275132     1
# 336.140680     1
# 220.321746     1
# ...

# %%
price_data["Country"].value_counts()
# Out:
# USA    41154
# Name: Country, dtype: int64

# %%
sq_data["Country"].value_counts()
# Out:
# USA    30389
# Name: Country, dtype: int64

# %%
home_df["bed_id"].value_counts()
# Out:
# 48423.000000    16
# 46263.974303     8
# 39325.000000     8
# 29206.443750     8
# 13248.958333     8
# 20232.648352     8
# 48614.459459     8
# 46520.181818     8
# 31235.141093     8
# 30207.581673     8
# 46255.023148     8
# 20307.569420     8
# 1192.456816      8
# 20109.666667     8
# 21233.292471     8
# 29152.009959     8
# 5155.865169      8
# 48393.796296     8
# 51450.799074     8
# 21271.784083     8
# 32134.000000     8
# 48188.258155     8
# 13153.083333     8
# 39387.000000     8
# 51283.488962     8
# 31184.257036     8
# 12279.231479     8
# 51631.380178     8
# 31122.716028     8
# 48460.318612     8
#                 ..
# 48724.373575     1
# 53136.754864     1
# 26141.760736     1
# 28226.333333     1
# 42068.375000     1
# 17190.814554     1
# 51265.267327     1
# 17047.107769     1
# 46231.819195     1
# 23156.556856     1
# 39154.701299     1
# 5103.045186      1
# 48595.627445     1
# 39137.939891     1
# 29308.984627     1
# 53290.258741     1
# ...

# %%
list(home_df)
# Out:
# ['Size Tier',
#  'MedianListingPrice M/M_x',
#  'MedianListingPrice Y/Y_x',
#  'bed_id',
#  'Countyfips_y',
#  'NoOfBdrs',
#  'Month',
#  'Countyfips',
#  'CountyName',
#  'Country',
#  'PropertyType',
#  'Price Tier',
#  'MedianListingSqft _y',
#  'MedianListingSqft M/M_y',
#  'MedianListingSqft Y/Y_y',
#  'MedianListingPricePerSqft',
#  'MedianListingPricePerSqft M/M',
#  'MedianListingPricePerSqft Y/Y']

# %%
home_df = home_df.drop(columns=['MedianListingPrice _y','MedianListingPrice M/M_y','MedianListingPrice Y/Y_y','MedianListingSqft _x','MedianListingSqft M/M_x','MedianListingSqft Y/Y_x','MedianListingPricePerSqft_y','MedianListingPricePerSqft M/M_y','MedianListingPricePerSqft Y/Y_y','PropertyType_y','Country_y','CountyName_y','Month_y','MedianListingPricePerSqft Y/Y_x','MedianListingPricePerSqft M/M_x','MedianListingPricePerSqft_x','PropertyType_x','Country_x','CountyName_x','Countyfips_x','Month_x'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-281-0a6c3d27405b> in <module>()
# ----> 1 home_df = home_df.drop(columns=['MedianListingPrice _y','MedianListingPrice M/M_y','MedianListingPrice Y/Y_y','MedianListingSqft _x','MedianListingSqft M/M_x','MedianListingSqft Y/Y_x','MedianListingPricePerSqft_y','MedianListingPricePerSqft M/M_y','MedianListingPricePerSqft Y/Y_y','PropertyType_y','Country_y','CountyName_y','Month_y','MedianListingPricePerSqft Y/Y_x','MedianListingPricePerSqft M/M_x','MedianListingPricePerSqft_x','PropertyType_x','Country_x','CountyName_x','Countyfips_x','Month_x'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
# ...

# %%
home_df
# Out:
#              Size Tier  MedianListingPrice M/M_x  MedianListingPrice Y/Y_x  \
# 5           sqft_0_750                    0.0000                   -0.4255
# 14          sqft_0_750                    0.0000                       NaN
# 28          sqft_0_750                    0.0000                   -0.0800
# 61          sqft_0_750                    0.0000                   -0.0213
# 69          sqft_0_750                    0.0000                   -0.6871
# 84          sqft_0_750                    0.0000                   -0.4761
# 87          sqft_0_750                   -0.0104                    0.0626
# 89          sqft_0_750                    0.0000                       NaN
# 90          sqft_0_750                    0.0000                       NaN
# 128         sqft_0_750                    0.0000                    0.0000
# 129         sqft_0_750                    0.0000                       NaN
# ...

# %%
home_df.to_csv("homes_data.csv", sep=',', encoding='utf-8')
