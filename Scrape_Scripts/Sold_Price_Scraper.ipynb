# %%
## Import Dependencies
from urllib.request import urlopen
import requests
from splinter import Browser
from bs4 import BeautifulSoup

## Initialize Chrome Driver

executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
browser.wait_time = 10

## Visit target url(s) to scrape

url = 'https://www.realtytrac.com/mapsearch/sold/il/cook-county/'
browser.visit(url)

## prettify page_html with urllib.requests and soup

html = urlopen('https://www.realtytrac.com/mapsearch/sold/il/cook-county/')
soup = BeautifulSoup(html, 'html.parser')
# print(soup.prettify())

filename = "sell_price_test.csv"
f = open(filename, "w")

headers = "Sell_Price \n"

f.write(headers)

def homes():
# Iterate through all pages
    for x in range(1,4440):
    # HTML object

        html = browser.html
    # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(html, 'html.parser')

        homes_sold = soup.find_all('div', {'class': 'price-info'})


        for home in homes_sold:
    # Use Beautiful Soup's find() method to navigate and retrieve attributes
#             address_data = home.find('div', {'class': 'address-data'})
#             home_address = address_data.h2.a
#             sell_data = home.find('div', {'class': 'price-info'})
            sell_price = home.find('dd', {'class': 'price'})
            sell_price = sell_price.text
#             sell_price = sell_price.strip()
            
           
          
        
            print('-----------')
#             print(home_address.text)
            print(sell_price)
            f.write(sell_price+ "\n")

        browser.click_link_by_partial_text('Next')


# for _ in range(10):
homes()



f.close()

# %%
from urllib.request import urlopen
import requests
# from splinter import Browser
from bs4 import BeautifulSoup

base_url = 'https://www.realtytrac.com/mapsearch/real-estate/il/cook-county/p-'

filename = "county_county_sold_price_test.csv"
f = open(filename, "w")

headers = "Sell_Price \n"

f.write(headers)

def homes():
# Iterate through all pages
    urls = [base_url+str(x) for x in range(0,320)]
    for url in urls: 
#     for x in range(1,100):
    # HTML object
        req = requests.get(url)

        html = req.content
    # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(html, 'html.parser')
        homes_sold = soup.find_all('div', {'class': 'price-info'})


        for home in homes_sold:
    # Use Beautiful Soup's find() method to navigate and retrieve attributes
#             address_data = home.find('div', {'class': 'address-data'})
#             home_address = address_data.h2.a
#             sell_data = home.find('div', {'class': 'price-info'})
            sell_price = home.find('dd', {'class': 'price'})
            sell_price = sell_price.text
#             sell_price = sell_price.strip()
            
           
          
        
#             print('-----------')
#             print(home_address.text)
#             print(sell_price)
            f.write(sell_price+ "\n")


homes()



f.close()
